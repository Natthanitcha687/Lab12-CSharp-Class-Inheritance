// %% [markdown]
// # Lab 12 Class Inheritance

// %% [markdown]
// ## Exercise 2 การใช้งาน method และ field ของ base และ  derived class

// %% [markdown]
// 1. สร้าง console application project
//
// > ```cmd
// > dotnet new console --name Lab12_Ex02
// > ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// var dc = new DerivedClass();
// dc.Method1(dc.Field1);  // call with method and field of base class
// dc.Method2(dc.Field1);  // call with method of derived class and field of base class
// dc.Method1(dc.Field2);  // call with method of base class and field of derived class
// dc.Method2(dc.Field2);  // call with method and field of derived class
//
// class BaseClass
// {
//     public string Field1 = "Field 1 in BaseClass";
//     public void Method1(string value)
//     {
//         System.Console.WriteLine($"Method1() in BaseClass, string input = {value} ");
//     }
// }
// class DerivedClass: BaseClass
// {
//     public string Field2 = "Field 2 in DerivedClass";
//     public void Method2(string value)
//     {
//         System.Console.WriteLine($"Method2() in DerivedClass, string input = {value} ");
//     }
//
// }
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab12_Ex02
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet run --project Lab12_Ex02
// ```

// %% [markdown]
// $ dotnet run --project Lab12_Ex02
// Method1() in BaseClass, string input = Field 1 in BaseClass
// Method2() in DerivedClass, string input = Field 1 in BaseClass
// Method1() in BaseClass, string input = Field 2 in DerivedClass
// Method2() in DerivedClass, string input = Field 2 in DerivedClass

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// โค้ดนี้แสดงให้เห็นถึงการสืบทอดคลาส คลาสลูก (DerivedClass) สามารถเข้าถึงและใช้งานสมาชิก (ฟิลด์และเมธอด) ทั้งหมดของคลาสแม่ (BaseClass) ได้ เหมือนกับว่ามีสมาชิกเหล่านั้นอยู่ในคลาสลูกด้วย ทำให้เราสามารถนำโค้ดเก่าของคลาสแม่มาใช้ซ้ำในคลาสลูกได้โดยไม่ต้องเขียนใหม่

// %% [markdown]
// ## คำถาม

// %% [markdown]
// 1. ให้เขียน mermaid diagram ของ code ในข้อ 2

// %%
sequenceDiagram
    participant DC as DerivedClass
    participant BC as BaseClass

    activate DC
    DC->>DC: var dc = new DerivedClass()
    DC->>DC: dc.Field1 = "Field 1 in BaseClass"
    DC->>DC: dc.Field2 = "Field 2 in DerivedClass"

    DC->>BC: dc.Method1(dc.Field1)
    activate BC
    BC-->>DC: Method1() in BaseClass, string input = Field 1 in BaseClass
    deactivate BC

    DC->>DC: dc.Method2(dc.Field1)
    DC-->>DC: Method2() in DerivedClass, string input = Field 1 in BaseClass

    DC->>BC: dc.Method1(dc.Field2)
    activate BC
    BC-->>DC: Method1() in BaseClass, string input = Field 2 in DerivedClass
    deactivate BC

    DC->>DC: dc.Method2(dc.Field2)
    DC-->>DC: Method2() in DerivedClass, string input = Field 2 in DerivedClass
    deactivate DC
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="e6e3493e276e46fe8e851d54d61fa39c"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('e6e3493e276e46fe8e851d54d61fa39c');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_e6e3493e276e46fe8e851d54d61fa39c',
//                     `sequenceDiagram
//     participant DC as DerivedClass
//     participant BC as BaseClass
//
//     activate DC
//     DC->>DC: var dc = new DerivedClass()
//     DC->>DC: dc.Field1 = "Field 1 in BaseClass"
//     DC->>DC: dc.Field2 = "Field 2 in DerivedClass"
//
//     DC->>BC: dc.Method1(dc.Field1)
//     activate BC
//     BC-->>DC: Method1() in BaseClass, string input = Field 1 in BaseClass
//     deactivate BC
//
//     DC->>DC: dc.Method2(dc.Field1)
//     DC-->>DC: Method2() in DerivedClass, string input = Field 1 in BaseClass
//
//     DC->>BC: dc.Method1(dc.Field2)
//     activate BC
//     BC-->>DC: Method1() in BaseClass, string input = Field 2 in DerivedClass
//     deactivate BC
//
//     DC->>DC: dc.Method2(dc.Field2)
//     DC-->>DC: Method2() in DerivedClass, string input = Field 2 in DerivedClass
//     deactivate DC`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>
